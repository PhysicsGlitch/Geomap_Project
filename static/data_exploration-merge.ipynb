# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
import os
from config2 import app_token

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", none)

# Example authenticated client (needed for non-public datasets):
# client = Socrata("data.cityofchicago.org",
#                  "du5ugsgl0w1g4ql37x78pjbc5",
#                  username= "dr.harmony",
#                  password= "F3ar&Loathing")

# # Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                 app_token)
#                  username= username,
#                  password= password)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("85ca-t3if", limit = 500000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                                           crash_record_id  \
# 0       1ff1c652d07797a23007a91553a5ce617e3265bb77e587...
# 1       0d7e68cad33d1e30335a3dd13ec444d757295595e67cfd...
# 2       e4a21c9f960eaae6f2a470f5444fff8a387dd41d6385cd...
# 3       c02e39af853ea20ff1a4cfc1dc23537a56a50c87ef25b9...
# 4       e4f296733029fc47d771e6a2e0544e9f27e90e5bdbb547...
# ...                                                   ...
# 445496  964aaaeb569e364886cfbdf89ca73e09ca15cd916d87b2...
# 445497  1d0232afecbdfd01968555aa956a688fd6f55a2bd1984f...
# 445498  957783a4787318f005a7dbc920e4c84cb9ac8aa7329a62...
# 445499  f62e27317feb174811cf4fefeb9fa1064fea6c0619a873...
# 445500  a802658be15312809c771559e4f81088cfb226830792a5...
#
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-07T00:05:00.000                 30         TRAFFIC SIGNAL
# 1       2020-10-06T23:17:00.000                 15            NO CONTROLS
# 2       2020-10-06T22:59:00.000                 15            NO CONTROLS
# 3       2020-10-06T22:42:00.000                 30            NO CONTROLS
# 4       2020-10-06T22:21:00.000                 30         TRAFFIC SIGNAL
# ...                         ...                ...                    ...
# 445496  2014-06-25T19:00:00.000                 30            NO CONTROLS
# 445497  2014-02-24T19:45:00.000                 30         TRAFFIC SIGNAL
# 445498  2014-01-21T07:40:00.000                 30                  YIELD
# 445499  2014-01-18T18:14:00.000                 30            NO CONTROLS
# 445500  2013-03-03T16:48:00.000                 30         TRAFFIC SIGNAL
#
#             device_condition weather_condition      lighting_condition  \
# 0       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 1                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 2                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 3                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 4       FUNCTIONING PROPERLY             CLEAR                DARKNESS
# ...                      ...               ...                     ...
# 445496           NO CONTROLS              RAIN                DAYLIGHT
# 445497  FUNCTIONING PROPERLY              RAIN                DAYLIGHT
# 445498           NO CONTROLS             CLEAR                DAYLIGHT
# 445499           NO CONTROLS             CLEAR                    DUSK
# 445500  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#                     first_crash_type                  trafficway_type  \
# 0                            TURNING                         FOUR WAY
# 1                       FIXED OBJECT                      NOT DIVIDED
# 2                       FIXED OBJECT                            ALLEY
# 3               PARKED MOTOR VEHICLE                            ALLEY
# 4                            TURNING                      NOT DIVIDED
# ...                              ...                              ...
# 445496      SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 445497                       TURNING                      NOT DIVIDED
# 445498                         ANGLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 445499          PARKED MOTOR VEHICLE       DIVIDED - W/MEDIAN BARRIER
# 445500  SIDESWIPE OPPOSITE DIRECTION                      NOT DIVIDED
#
#                  alignment  ... crash_date_est_i statements_taken_i  \
# 0       STRAIGHT AND LEVEL  ...              NaN                NaN
# 1       STRAIGHT AND LEVEL  ...              NaN                NaN
# 2       STRAIGHT AND LEVEL  ...              NaN                NaN
# 3       STRAIGHT AND LEVEL  ...                Y                NaN
# 4       STRAIGHT AND LEVEL  ...              NaN                NaN
# ...                    ...  ...              ...                ...
# 445496  STRAIGHT AND LEVEL  ...              NaN                NaN
# 445497  STRAIGHT AND LEVEL  ...              NaN                NaN
# 445498  STRAIGHT AND LEVEL  ...              NaN                NaN
# 445499  STRAIGHT AND LEVEL  ...              NaN                NaN
# 445500  STRAIGHT AND LEVEL  ...              NaN                NaN
#
#        private_property_i photos_taken_i work_zone_i dooring_i work_zone_type  \
# 0                     NaN            NaN         NaN       NaN            NaN
# 1                     NaN            NaN         NaN       NaN            NaN
# 2                     NaN            NaN         NaN       NaN            NaN
# 3                     NaN            NaN         NaN       NaN            NaN
# 4                     NaN            NaN         NaN       NaN            NaN
# ...                   ...            ...         ...       ...            ...
# 445496                NaN            NaN         NaN       NaN            NaN
# 445497                NaN            NaN         NaN       NaN            NaN
# 445498                NaN            NaN         NaN       NaN            NaN
# 445499                NaN            NaN         NaN       NaN            NaN
# 445500                NaN            NaN         NaN       NaN            NaN
#
#        workers_present_i     rd_no lane_cnt
# 0                    NaN       NaN      NaN
# 1                    NaN       NaN      NaN
# 2                    NaN       NaN      NaN
# 3                    NaN       NaN      NaN
# 4                    NaN       NaN      NaN
# ...                  ...       ...      ...
# 445496               NaN  JC321679      NaN
# 445497               NaN  HZ164689      NaN
# 445498               NaN  HZ122950      NaN
# 445499               NaN  JB442550      NaN
# 445500               NaN  JC172482        2
#
# [445501 rows x 49 columns]

# %%
results_df.columns
# Out:
# Index(['crash_record_id', 'crash_date', 'posted_speed_limit',
#        'traffic_control_device', 'device_condition', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'report_type',
#        'crash_type', 'intersection_related_i', 'damage',
#        'date_police_notified', 'prim_contributory_cause',
#        'sec_contributory_cause', 'street_no', 'street_direction',
#        'street_name', 'beat_of_occurrence', 'num_units', 'most_severe_injury',
#        'injuries_total', 'injuries_fatal', 'injuries_incapacitating',
#        'injuries_non_incapacitating', 'injuries_reported_not_evident',
#        'injuries_no_indication', 'injuries_unknown', 'crash_hour',
#        'crash_day_of_week', 'crash_month', 'latitude', 'longitude', 'location',
#        'hit_and_run_i', 'crash_date_est_i', 'statements_taken_i',
#        'private_property_i', 'photos_taken_i', 'work_zone_i', 'dooring_i',
#        'work_zone_type', 'workers_present_i', 'rd_no', 'lane_cnt'],
#       dtype='object')

# %%
crashes = results_df.drop(columns=['crash_record_id', 'location', 'injuries_unknown', 'injuries_incapacitating', 'injuries_fatal', 'injuries_no_indication', 'injuries_reported_not_evident', 'injuries_non_incapacitating', 'private_property_i', 'crash_date_est_i', 'statements_taken_i', 'photos_taken_i', 'work_zone_i', 'work_zone_type', 'workers_present_i', 'dooring_i'])
crashes
# Out:
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-07T00:05:00.000                 30         TRAFFIC SIGNAL
# 1       2020-10-06T23:17:00.000                 15            NO CONTROLS
# 2       2020-10-06T22:59:00.000                 15            NO CONTROLS
# 3       2020-10-06T22:42:00.000                 30            NO CONTROLS
# 4       2020-10-06T22:21:00.000                 30         TRAFFIC SIGNAL
# ...                         ...                ...                    ...
# 445496  2014-06-25T19:00:00.000                 30            NO CONTROLS
# 445497  2014-02-24T19:45:00.000                 30         TRAFFIC SIGNAL
# 445498  2014-01-21T07:40:00.000                 30                  YIELD
# 445499  2014-01-18T18:14:00.000                 30            NO CONTROLS
# 445500  2013-03-03T16:48:00.000                 30         TRAFFIC SIGNAL
#
#             device_condition weather_condition      lighting_condition  \
# 0       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 1                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 2                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 3                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 4       FUNCTIONING PROPERLY             CLEAR                DARKNESS
# ...                      ...               ...                     ...
# 445496           NO CONTROLS              RAIN                DAYLIGHT
# 445497  FUNCTIONING PROPERLY              RAIN                DAYLIGHT
# 445498           NO CONTROLS             CLEAR                DAYLIGHT
# 445499           NO CONTROLS             CLEAR                    DUSK
# 445500  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#                     first_crash_type                  trafficway_type  \
# 0                            TURNING                         FOUR WAY
# 1                       FIXED OBJECT                      NOT DIVIDED
# 2                       FIXED OBJECT                            ALLEY
# 3               PARKED MOTOR VEHICLE                            ALLEY
# 4                            TURNING                      NOT DIVIDED
# ...                              ...                              ...
# 445496      SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 445497                       TURNING                      NOT DIVIDED
# 445498                         ANGLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 445499          PARKED MOTOR VEHICLE       DIVIDED - W/MEDIAN BARRIER
# 445500  SIDESWIPE OPPOSITE DIRECTION                      NOT DIVIDED
#
#                  alignment roadway_surface_cond  ...  \
# 0       STRAIGHT AND LEVEL                  DRY  ...
# 1       STRAIGHT AND LEVEL                  DRY  ...
# 2       STRAIGHT AND LEVEL                  DRY  ...
# 3       STRAIGHT AND LEVEL              UNKNOWN  ...
# 4       STRAIGHT AND LEVEL                  DRY  ...
# ...                    ...                  ...  ...
# 445496  STRAIGHT AND LEVEL                  WET  ...
# 445497  STRAIGHT AND LEVEL                  WET  ...
# 445498  STRAIGHT AND LEVEL                  DRY  ...
# 445499  STRAIGHT AND LEVEL                  DRY  ...
# 445500  STRAIGHT AND LEVEL                  DRY  ...
#
#               most_severe_injury injuries_total crash_hour crash_day_of_week  \
# 0        NO INDICATION OF INJURY              0          0                 4
# 1        NO INDICATION OF INJURY              0         23                 3
# 2        NO INDICATION OF INJURY              0         22                 3
# 3       NONINCAPACITATING INJURY              1         22                 3
# 4        NO INDICATION OF INJURY              0         22                 3
# ...                          ...            ...        ...               ...
# 445496   NO INDICATION OF INJURY              0         19                 4
# 445497   NO INDICATION OF INJURY              0         19                 2
# 445498  NONINCAPACITATING INJURY              1          7                 3
# 445499   NO INDICATION OF INJURY              0         18                 7
# 445500     REPORTED, NOT EVIDENT              2         16                 1
#
#        crash_month      latitude      longitude hit_and_run_i     rd_no  \
# 0               10  41.857744853  -87.627341378           NaN       NaN
# 1               10  41.886713149  -87.739943792             Y       NaN
# 2               10  41.878273207  -87.761878438           NaN       NaN
# 3               10  41.875834619  -87.757314757             N       NaN
# 4               10   41.75150394  -87.575328551             Y       NaN
# ...            ...           ...            ...           ...       ...
# 445496           6  41.835886103  -87.724474013             Y  JC321679
# 445497           2  41.884016475  -87.701142758           NaN  HZ164689
# 445498           1  41.760710194   -87.56194603           NaN  HZ122950
# 445499           1  41.885609917   -87.63875619           NaN  JB442550
# 445500           3  41.975856916  -87.708743642             Y  JC172482
#
#        lane_cnt
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 445496      NaN
# 445497      NaN
# 445498      NaN
# 445499      NaN
# 445500        2
#
# [445501 rows x 33 columns]

# %%
crashes.rename(columns={"beat_of_occurrence": "Beat"}, inplace = True)

# %%
crashes.dtypes
# Out:
# crash_date                 object
# posted_speed_limit         object
# traffic_control_device     object
# device_condition           object
# weather_condition          object
# lighting_condition         object
# first_crash_type           object
# trafficway_type            object
# alignment                  object
# roadway_surface_cond       object
# road_defect                object
# report_type                object
# crash_type                 object
# intersection_related_i     object
# damage                     object
# date_police_notified       object
# prim_contributory_cause    object
# sec_contributory_cause     object
# street_no                  object
# street_direction           object
# street_name                object
# Beat                       object
# num_units                  object
# most_severe_injury         object
# injuries_total             object
# crash_hour                 object
# crash_day_of_week          object
# crash_month                object
# latitude                   object
# longitude                  object
# hit_and_run_i              object
# rd_no                      object
# lane_cnt                   object
# dtype: object

# %%
crashes[["Beat"]] = crashes[["Beat"]].apply(pd.to_numeric)
crashes.dtypes
# Out:
# crash_date                  object
# posted_speed_limit          object
# traffic_control_device      object
# device_condition            object
# weather_condition           object
# lighting_condition          object
# first_crash_type            object
# trafficway_type             object
# alignment                   object
# roadway_surface_cond        object
# road_defect                 object
# report_type                 object
# crash_type                  object
# intersection_related_i      object
# damage                      object
# date_police_notified        object
# prim_contributory_cause     object
# sec_contributory_cause      object
# street_no                   object
# street_direction            object
# street_name                 object
# Beat                       float64
# num_units                   object
# most_severe_injury          object
# injuries_total              object
# crash_hour                  object
# crash_day_of_week           object
# crash_month                 object
# latitude                    object
# longitude                   object
# hit_and_run_i               object
# rd_no                       object
# lane_cnt                    object
# dtype: object

# %%
# Reference the file where the CSV is located
neighborhood_path = "ChicagoAreasBeatDistricts.csv"

# Import the data into a Pandas DataFrame
neighborhoods_df = pd.read_csv(neighborhood_path)
neighborhoods_df.dtypes
# Out:
# Beat              int64
# District          int64
# Community Area    int64
# dtype: object

# %%
crash_neighborhood_merge = pd.merge(left=crashes, right=neighborhoods_df, how='right', on=['Beat'])
# crash_neighborhood_merge = pd.concat([crashes, neighborhoods_df], axis=1)
crash_neighborhood_merge_clean = crash_neighborhood_merge[['crash_date', 'posted_speed_limit', 'traffic_control_device',
       'device_condition', 'weather_condition', 'lighting_condition',
       'first_crash_type', 'trafficway_type', 'alignment',
       'roadway_surface_cond', 'road_defect', 'report_type', 'crash_type',
       'intersection_related_i', 'damage', 'date_police_notified',
       'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
       'street_direction', 'street_name', 'District', 'Community Area', 'Beat', 'num_units',
       'most_severe_injury', 'injuries_total', 'crash_hour',
       'crash_day_of_week', 'crash_month', 'latitude', 'longitude',
       'hit_and_run_i', 'rd_no', 'lane_cnt']]
crash_neighborhood_merge_clean
# Out:
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-07T00:05:00.000                 30         TRAFFIC SIGNAL
# 1       2020-10-06T10:00:00.000                 30            NO CONTROLS
# 2       2020-10-05T17:45:00.000                 15            NO CONTROLS
# 3       2020-10-05T16:18:00.000                 15            NO CONTROLS
# 4       2020-10-03T14:01:00.000                 30            NO CONTROLS
# ...                         ...                ...                    ...
# 863265  2018-08-09T17:45:00.000                 30            NO CONTROLS
# 863266  2018-08-02T21:45:00.000                 30            NO CONTROLS
# 863267  2018-07-16T05:40:00.000                 20            NO CONTROLS
# 863268  2018-07-10T07:10:00.000                 30            NO CONTROLS
# 863269  2018-06-14T03:50:00.000                 20            NO CONTROLS
#
#             device_condition weather_condition      lighting_condition  \
# 0       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 1                NO CONTROLS             CLEAR                DAYLIGHT
# 2                NO CONTROLS             CLEAR                    DAWN
# 3                NO CONTROLS             CLEAR                DAYLIGHT
# 4                NO CONTROLS             CLEAR                DAYLIGHT
# ...                      ...               ...                     ...
# 863265           NO CONTROLS             CLEAR                DAYLIGHT
# 863266           NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 863267           NO CONTROLS             CLEAR                DAYLIGHT
# 863268           NO CONTROLS             CLEAR                DAYLIGHT
# 863269           NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
#
#                 first_crash_type                  trafficway_type  \
# 0                        TURNING                         FOUR WAY
# 1           PARKED MOTOR VEHICLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 2           PARKED MOTOR VEHICLE                      PARKING LOT
# 3           PARKED MOTOR VEHICLE                      PARKING LOT
# 4                        TURNING                      NOT DIVIDED
# ...                          ...                              ...
# 863265                  REAR END                             RAMP
# 863266  SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 863267  SIDESWIPE SAME DIRECTION                          ONE-WAY
# 863268  SIDESWIPE SAME DIRECTION                            OTHER
# 863269  SIDESWIPE SAME DIRECTION                          ONE-WAY
#
#                  alignment roadway_surface_cond  ...       most_severe_injury  \
# 0       STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 1       STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 2       STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 3       STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 4       STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# ...                    ...                  ...  ...                      ...
# 863265  STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 863266  STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 863267  STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 863268  STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
# 863269  STRAIGHT AND LEVEL                  DRY  ...  NO INDICATION OF INJURY
#
#        injuries_total crash_hour crash_day_of_week crash_month      latitude  \
# 0                   0          0                 4          10  41.857744853
# 1                   0         10                 3          10  41.853766723
# 2                   0         17                 2          10    41.8544114
# 3                   0         16                 2          10  41.859629677
# 4                   0         14                 7          10  41.866776213
# ...               ...        ...               ...         ...           ...
# 863265              0         17                 5           8           NaN
# 863266              0         21                 5           8           NaN
# 863267              0          5                 2           7           NaN
# 863268              0          7                 3           7           NaN
# 863269              0          3                 5           6           NaN
#
#             longitude hit_and_run_i     rd_no lane_cnt
# 0       -87.627341378           NaN       NaN      NaN
# 1       -87.625665167             Y       NaN      NaN
# 2       -87.629991876           NaN       NaN      NaN
# 3       -87.630124899           NaN       NaN      NaN
# 4       -87.625962198           NaN       NaN      NaN
# ...               ...           ...       ...      ...
# 863265            NaN           NaN  JB387944        4
# 863266            NaN           NaN  JB377421      NaN
# 863267            NaN           NaN  JB351498      NaN
# 863268            NaN           NaN  JB343207        2
# 863269            NaN           NaN  JB306057        3
#
# [863270 rows x 35 columns]

# %%
crash_neighborhood_merge_clean.columns
# Out:
# Index(['crash_date', 'posted_speed_limit', 'traffic_control_device',
#        'device_condition', 'weather_condition', 'lighting_condition',
#        'first_crash_type', 'trafficway_type', 'alignment',
#        'roadway_surface_cond', 'road_defect', 'report_type', 'crash_type',
#        'intersection_related_i', 'damage', 'date_police_notified',
#        'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
#        'street_direction', 'street_name', 'District', 'Community Area', 'Beat',
#        'num_units', 'most_severe_injury', 'injuries_total', 'crash_hour',
#        'crash_day_of_week', 'crash_month', 'latitude', 'longitude',
#        'hit_and_run_i', 'rd_no', 'lane_cnt'],
#       dtype='object')

# %%
file_location = os.path.join('crashes.json')
crash_neighborhood_merge_clean.to_json(file_location)

# %%
# finalhtml = crash_neighborhood_merge_clean.to_html('crashes.html')
