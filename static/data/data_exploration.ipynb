# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
import os
from config2 import app_token

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", none)

# Example authenticated client (needed for non-public datasets):
# client = Socrata("data.cityofchicago.org",
#                  "du5ugsgl0w1g4ql37x78pjbc5",
#                  username= "dr.harmony",
#                  password= "F3ar&Loathing")

# # Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                 app_token)
#                  username= username,
#                  password= password)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("85ca-t3if", limit = 500000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                                           crash_record_id  \
# 0       e7ebf3c521b989db35c15ef27c140ce262ea60fb0b42cd...
# 1       cb86d622709d797f6120f31de88256d8ae29eda16d3bbc...
# 2       e56551f10fbb1f3adfed04d54b924c7eb7bb8aa1731d73...
# 3       fc0b680577dcb56ed3ccdc0f005fe8fa36aee0a85e677f...
# 4       f1258057a85a5950f9044c98f462b73c2faf6b3cb396df...
# ...                                                   ...
# 447626  964aaaeb569e364886cfbdf89ca73e09ca15cd916d87b2...
# 447627  1d0232afecbdfd01968555aa956a688fd6f55a2bd1984f...
# 447628  957783a4787318f005a7dbc920e4c84cb9ac8aa7329a62...
# 447629  f62e27317feb174811cf4fefeb9fa1064fea6c0619a873...
# 447630  a802658be15312809c771559e4f81088cfb226830792a5...
#
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-15T00:45:00.000                 30            NO CONTROLS
# 1       2020-10-14T23:40:00.000                 30            NO CONTROLS
# 2       2020-10-14T22:30:00.000                 30      STOP SIGN/FLASHER
# 3       2020-10-14T22:29:00.000                 30            NO CONTROLS
# 4       2020-10-14T21:40:00.000                 30      STOP SIGN/FLASHER
# ...                         ...                ...                    ...
# 447626  2014-06-25T19:00:00.000                 30            NO CONTROLS
# 447627  2014-02-24T19:45:00.000                 30         TRAFFIC SIGNAL
# 447628  2014-01-21T07:40:00.000                 30                  YIELD
# 447629  2014-01-18T18:14:00.000                 30            NO CONTROLS
# 447630  2013-03-03T16:48:00.000                 30         TRAFFIC SIGNAL
#
#             device_condition weather_condition      lighting_condition  \
# 0                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 1                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 2                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 3                NO CONTROLS             CLEAR                DARKNESS
# 4       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# ...                      ...               ...                     ...
# 447626           NO CONTROLS              RAIN                DAYLIGHT
# 447627  FUNCTIONING PROPERLY              RAIN                DAYLIGHT
# 447628           NO CONTROLS             CLEAR                DAYLIGHT
# 447629           NO CONTROLS             CLEAR                    DUSK
# 447630  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#                     first_crash_type                  trafficway_type  \
# 0           SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 1                       FIXED OBJECT                      NOT DIVIDED
# 2                              ANGLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 3               PARKED MOTOR VEHICLE                      NOT DIVIDED
# 4                              ANGLE                      NOT DIVIDED
# ...                              ...                              ...
# 447626      SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 447627                       TURNING                      NOT DIVIDED
# 447628                         ANGLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 447629          PARKED MOTOR VEHICLE       DIVIDED - W/MEDIAN BARRIER
# 447630  SIDESWIPE OPPOSITE DIRECTION                      NOT DIVIDED
#
#                  alignment  ... statements_taken_i private_property_i  \
# 0       STRAIGHT AND LEVEL  ...                NaN                NaN
# 1       STRAIGHT AND LEVEL  ...                NaN                NaN
# 2       STRAIGHT AND LEVEL  ...                NaN                NaN
# 3       STRAIGHT AND LEVEL  ...                NaN                NaN
# 4       STRAIGHT AND LEVEL  ...                NaN                NaN
# ...                    ...  ...                ...                ...
# 447626  STRAIGHT AND LEVEL  ...                NaN                NaN
# 447627  STRAIGHT AND LEVEL  ...                NaN                NaN
# 447628  STRAIGHT AND LEVEL  ...                NaN                NaN
# 447629  STRAIGHT AND LEVEL  ...                NaN                NaN
# 447630  STRAIGHT AND LEVEL  ...                NaN                NaN
#
#        crash_date_est_i dooring_i work_zone_i work_zone_type photos_taken_i  \
# 0                   NaN       NaN         NaN            NaN            NaN
# 1                   NaN       NaN         NaN            NaN            NaN
# 2                   NaN       NaN         NaN            NaN            NaN
# 3                   NaN       NaN         NaN            NaN            NaN
# 4                   NaN       NaN         NaN            NaN            NaN
# ...                 ...       ...         ...            ...            ...
# 447626              NaN       NaN         NaN            NaN            NaN
# 447627              NaN       NaN         NaN            NaN            NaN
# 447628              NaN       NaN         NaN            NaN            NaN
# 447629              NaN       NaN         NaN            NaN            NaN
# 447630              NaN       NaN         NaN            NaN            NaN
#
#        workers_present_i     rd_no lane_cnt
# 0                    NaN       NaN      NaN
# 1                    NaN       NaN      NaN
# 2                    NaN       NaN      NaN
# 3                    NaN       NaN      NaN
# 4                    NaN       NaN      NaN
# ...                  ...       ...      ...
# 447626               NaN  JC321679      NaN
# 447627               NaN  HZ164689      NaN
# 447628               NaN  HZ122950      NaN
# 447629               NaN  JB442550      NaN
# 447630               NaN  JC172482        2
#
# [447631 rows x 49 columns]

# %%
datatoload = "ChicagoAreasBeatDistricts.csv"
datawork = pd.read_csv(datatoload)

datawork
# Out:
#      Beat  District  Community Area
# 0    2432        24               1
# 1    2423        24               1
# 2    2424        24               1
# 3    2422        24               1
# 4    2431        24               1
# ..    ...       ...             ...
# 501  2022        20              77
# 502  2023        20              77
# 503  2013        20              77
# 504  2012        20              77
# 505  2013        25              77
#
# [506 rows x 3 columns]

# %%
results_df.columns
# Out:
# Index(['crash_record_id', 'crash_date', 'posted_speed_limit',
#        'traffic_control_device', 'device_condition', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'report_type',
#        'crash_type', 'damage', 'date_police_notified',
#        'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
#        'street_direction', 'street_name', 'beat_of_occurrence', 'num_units',
#        'most_severe_injury', 'injuries_total', 'injuries_fatal',
#        'injuries_incapacitating', 'injuries_non_incapacitating',
#        'injuries_reported_not_evident', 'injuries_no_indication',
#        'injuries_unknown', 'crash_hour', 'crash_day_of_week', 'crash_month',
#        'latitude', 'longitude', 'location', 'hit_and_run_i',
#        'intersection_related_i', 'crash_date_est_i', 'private_property_i',
#        'statements_taken_i', 'photos_taken_i', 'work_zone_i', 'work_zone_type',
#        'workers_present_i', 'dooring_i', 'rd_no', 'lane_cnt'],
#       dtype='object')

# %%
crashes = results_df.drop(columns=['crash_record_id', 'location', 'injuries_unknown', 'injuries_incapacitating', 'injuries_fatal', 'injuries_no_indication', 'injuries_reported_not_evident', 'injuries_non_incapacitating', 'private_property_i', 'crash_date_est_i', 'statements_taken_i', 'photos_taken_i', 'work_zone_i', 'work_zone_type', 'workers_present_i', 'dooring_i'])
crashes
# Out:
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-14T00:33:00.000                 30      STOP SIGN/FLASHER
# 1       2020-10-14T00:13:00.000                 25      STOP SIGN/FLASHER
# 2       2020-10-13T23:42:00.000                 30      STOP SIGN/FLASHER
# 3       2020-10-13T22:41:00.000                 30         TRAFFIC SIGNAL
# 4       2020-10-13T22:00:00.000                 30                UNKNOWN
# ...                         ...                ...                    ...
# 447367  2014-06-25T19:00:00.000                 30            NO CONTROLS
# 447368  2014-02-24T19:45:00.000                 30         TRAFFIC SIGNAL
# 447369  2014-01-21T07:40:00.000                 30                  YIELD
# 447370  2014-01-18T18:14:00.000                 30            NO CONTROLS
# 447371  2013-03-03T16:48:00.000                 30         TRAFFIC SIGNAL
#
#             device_condition weather_condition      lighting_condition  \
# 0                      OTHER             CLEAR  DARKNESS, LIGHTED ROAD
# 1       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 2       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 3       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 4       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# ...                      ...               ...                     ...
# 447367           NO CONTROLS              RAIN                DAYLIGHT
# 447368  FUNCTIONING PROPERLY              RAIN                DAYLIGHT
# 447369           NO CONTROLS             CLEAR                DAYLIGHT
# 447370           NO CONTROLS             CLEAR                    DUSK
# 447371  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#                     first_crash_type                  trafficway_type  \
# 0                       FIXED OBJECT                      NOT DIVIDED
# 1               PARKED MOTOR VEHICLE                      NOT DIVIDED
# 2                              ANGLE                         FOUR WAY
# 3           SIDESWIPE SAME DIRECTION                 CENTER TURN LANE
# 4               PARKED MOTOR VEHICLE  DIVIDED - W/MEDIAN (NOT RAISED)
# ...                              ...                              ...
# 447367      SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 447368                       TURNING                      NOT DIVIDED
# 447369                         ANGLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 447370          PARKED MOTOR VEHICLE       DIVIDED - W/MEDIAN BARRIER
# 447371  SIDESWIPE OPPOSITE DIRECTION                      NOT DIVIDED
#
#                  alignment roadway_surface_cond  ... injuries_total  \
# 0       STRAIGHT AND LEVEL                  DRY  ...              0
# 1       STRAIGHT AND LEVEL                  DRY  ...              0
# 2       STRAIGHT AND LEVEL                  DRY  ...              2
# 3       STRAIGHT AND LEVEL                  DRY  ...              0
# 4       STRAIGHT AND LEVEL                  DRY  ...              0
# ...                    ...                  ...  ...            ...
# 447367  STRAIGHT AND LEVEL                  WET  ...              0
# 447368  STRAIGHT AND LEVEL                  WET  ...              0
# 447369  STRAIGHT AND LEVEL                  DRY  ...              1
# 447370  STRAIGHT AND LEVEL                  DRY  ...              0
# 447371  STRAIGHT AND LEVEL                  DRY  ...              2
#
#        crash_hour crash_day_of_week crash_month      latitude      longitude  \
# 0               0                 4          10  41.891849778  -87.721015866
# 1               0                 4          10  42.005081869  -87.693660959
# 2              23                 3          10  41.672575037  -87.629564171
# 3              22                 3          10  41.998217921  -87.660695256
# 4              22                 3          10  41.902052839  -87.721557289
# ...           ...               ...         ...           ...            ...
# 447367         19                 4           6  41.835886103  -87.724474013
# 447368         19                 2           2  41.884016475  -87.701142758
# 447369          7                 3           1  41.760710194   -87.56194603
# 447370         18                 7           1  41.885609917   -87.63875619
# 447371         16                 1           3  41.975856916  -87.708743642
#
#        hit_and_run_i intersection_related_i     rd_no lane_cnt
# 0                NaN                    NaN       NaN      NaN
# 1                  Y                    NaN       NaN      NaN
# 2                  Y                      Y       NaN      NaN
# 3                NaN                      Y       NaN      NaN
# 4                  Y                    NaN       NaN      NaN
# ...              ...                    ...       ...      ...
# 447367             Y                    NaN  JC321679      NaN
# 447368           NaN                    NaN  HZ164689      NaN
# 447369           NaN                    NaN  HZ122950      NaN
# 447370           NaN                    NaN  JB442550      NaN
# 447371             Y                      Y  JC172482        2
#
# [447372 rows x 33 columns]

# %%
crashes.rename(columns={"beat_of_occurrence": "Beat"}, inplace = True)

# %%
crashes.dtypes
# Out:
# crash_date                 object
# posted_speed_limit         object
# traffic_control_device     object
# device_condition           object
# weather_condition          object
# lighting_condition         object
# first_crash_type           object
# trafficway_type            object
# alignment                  object
# roadway_surface_cond       object
# road_defect                object
# report_type                object
# crash_type                 object
# damage                     object
# date_police_notified       object
# prim_contributory_cause    object
# sec_contributory_cause     object
# street_no                  object
# street_direction           object
# street_name                object
# Beat                       object
# num_units                  object
# most_severe_injury         object
# injuries_total             object
# crash_hour                 object
# crash_day_of_week          object
# crash_month                object
# latitude                   object
# longitude                  object
# hit_and_run_i              object
# intersection_related_i     object
# rd_no                      object
# lane_cnt                   object
# dtype: object

# %%
crashes[["Beat"]] = crashes[["Beat"]].apply(pd.to_numeric)
crashes.dtypes
# Out:
# crash_date                  object
# posted_speed_limit          object
# traffic_control_device      object
# device_condition            object
# weather_condition           object
# lighting_condition          object
# first_crash_type            object
# trafficway_type             object
# alignment                   object
# roadway_surface_cond        object
# road_defect                 object
# report_type                 object
# crash_type                  object
# damage                      object
# date_police_notified        object
# prim_contributory_cause     object
# sec_contributory_cause      object
# street_no                   object
# street_direction            object
# street_name                 object
# Beat                       float64
# num_units                   object
# most_severe_injury          object
# injuries_total              object
# crash_hour                  object
# crash_day_of_week           object
# crash_month                 object
# latitude                    object
# longitude                   object
# hit_and_run_i               object
# intersection_related_i      object
# rd_no                       object
# lane_cnt                    object
# dtype: object

# %%
# Reference the file where the CSV is located
neighborhood_path = "ChicagoAreasBeatDistricts.csv"

# Import the data into a Pandas DataFrame
neighborhoods_df = pd.read_csv(neighborhood_path)
neighborhoods_df.dtypes
# Out:
# Beat              int64
# District          int64
# Community Area    int64
# dtype: object

# %%
crash_neighborhood_merge = pd.merge(left=crashes, right=neighborhoods_df, how='right', on=['Beat'])
# crash_neighborhood_merge = pd.concat([crashes, neighborhoods_df], axis=1)
crash_neighborhood_merge_clean = crash_neighborhood_merge[['crash_date', 'posted_speed_limit', 'traffic_control_device',
       'device_condition', 'weather_condition', 'lighting_condition',
       'first_crash_type', 'trafficway_type', 'alignment',
       'roadway_surface_cond', 'road_defect', 'report_type', 'crash_type',
       'intersection_related_i', 'damage', 'date_police_notified',
       'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
       'street_direction', 'street_name', 'District', 'Community Area', 'Beat', 'num_units',
       'most_severe_injury', 'injuries_total', 'crash_hour',
       'crash_day_of_week', 'crash_month', 'latitude', 'longitude',
       'hit_and_run_i', 'rd_no', 'lane_cnt']]
crash_neighborhood_merge_clean.groupby(by=["Community Area"]).head()
# Out:
#                      crash_date posted_speed_limit traffic_control_device  \
# 0       2020-10-14T00:33:00.000                 30      STOP SIGN/FLASHER
# 1       2020-10-12T16:50:00.000                 30            NO CONTROLS
# 2       2020-10-12T04:37:00.000                 30         TRAFFIC SIGNAL
# 3       2020-10-11T23:35:00.000                 30            NO CONTROLS
# 4       2020-10-11T10:17:00.000                 25            NO CONTROLS
# ...                         ...                ...                    ...
# 711689  2020-10-11T13:20:00.000                 30            NO CONTROLS
# 711690  2020-10-08T02:40:00.000                 30         TRAFFIC SIGNAL
# 711691  2020-10-07T02:50:00.000                 30         TRAFFIC SIGNAL
# 711692  2020-10-06T13:00:00.000                 36         TRAFFIC SIGNAL
# 711693  2020-10-05T17:51:00.000                 30         TRAFFIC SIGNAL
#
#             device_condition weather_condition      lighting_condition  \
# 0                      OTHER             CLEAR  DARKNESS, LIGHTED ROAD
# 1                NO CONTROLS             CLEAR                DAYLIGHT
# 2       FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 3                NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 4                NO CONTROLS             CLEAR                DAYLIGHT
# ...                      ...               ...                     ...
# 711689           NO CONTROLS             CLEAR                DAYLIGHT
# 711690  FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 711691  FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 711692  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
# 711693  FUNCTIONING PROPERLY             CLEAR                DAYLIGHT
#
#                 first_crash_type                  trafficway_type  \
# 0                   FIXED OBJECT                      NOT DIVIDED
# 1                   FIXED OBJECT  DIVIDED - W/MEDIAN (NOT RAISED)
# 2       SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 3       SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 4                   FIXED OBJECT                            ALLEY
# ...                          ...                              ...
# 711689  SIDESWIPE SAME DIRECTION                      NOT DIVIDED
# 711690                PEDESTRIAN                         FOUR WAY
# 711691                  REAR END                      NOT DIVIDED
# 711692                   TURNING                      NOT DIVIDED
# 711693                  REAR END                      NOT DIVIDED
#
#                     alignment roadway_surface_cond  ...  \
# 0          STRAIGHT AND LEVEL                  DRY  ...
# 1          STRAIGHT AND LEVEL                  DRY  ...
# 2          STRAIGHT AND LEVEL                  DRY  ...
# 3          STRAIGHT AND LEVEL                  DRY  ...
# 4          STRAIGHT AND LEVEL                  DRY  ...
# ...                       ...                  ...  ...
# 711689     STRAIGHT AND LEVEL                  DRY  ...
# 711690     STRAIGHT AND LEVEL                  DRY  ...
# 711691  STRAIGHT ON HILLCREST                  DRY  ...
# 711692     STRAIGHT AND LEVEL                  DRY  ...
# 711693     STRAIGHT AND LEVEL                  DRY  ...
#
#               most_severe_injury injuries_total crash_hour crash_day_of_week  \
# 0        NO INDICATION OF INJURY              0          0                 4
# 1        NO INDICATION OF INJURY              0         16                 2
# 2        NO INDICATION OF INJURY              0          4                 2
# 3        NO INDICATION OF INJURY              0         23                 1
# 4        NO INDICATION OF INJURY              0         10                 1
# ...                          ...            ...        ...               ...
# 711689   NO INDICATION OF INJURY              0         13                 1
# 711690  NONINCAPACITATING INJURY              1          2                 5
# 711691   NO INDICATION OF INJURY              0          2                 4
# 711692   NO INDICATION OF INJURY              0         13                 3
# 711693   NO INDICATION OF INJURY              0         17                 2
#
#        crash_month      latitude      longitude hit_and_run_i rd_no lane_cnt
# 0               10  41.891849778  -87.721015866           NaN   NaN      NaN
# 1               10  41.885323187  -87.725057879           NaN   NaN      NaN
# 2               10  41.877196784  -87.720483702             Y   NaN      NaN
# 3               10  41.881914545  -87.720256968           NaN   NaN      NaN
# 4               10  41.881981722  -87.723093299             Y   NaN      NaN
# ...            ...           ...            ...           ...   ...      ...
# 711689          10  41.677947075  -87.620613467             N   NaN      NaN
# 711690          10   41.68539921  -87.611247473             Y   NaN      NaN
# 711691          10  41.659583177  -87.597607376             Y   NaN      NaN
# 711692          10  41.663585976  -87.619889182           NaN   NaN      NaN
# 711693          10   41.66330385  -87.619166201             Y   NaN      NaN
#
# [385 rows x 35 columns]

# %%
crash_neighborhood_merge_clean.columns
# Out:
# Index(['crash_date', 'posted_speed_limit', 'traffic_control_device',
#        'device_condition', 'weather_condition', 'lighting_condition',
#        'first_crash_type', 'trafficway_type', 'alignment',
#        'roadway_surface_cond', 'road_defect', 'report_type', 'crash_type',
#        'intersection_related_i', 'damage', 'date_police_notified',
#        'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
#        'street_direction', 'street_name', 'District', 'Community Area', 'Beat',
#        'num_units', 'most_severe_injury', 'injuries_total', 'crash_hour',
#        'crash_day_of_week', 'crash_month', 'latitude', 'longitude',
#        'hit_and_run_i', 'rd_no', 'lane_cnt'],
#       dtype='object')

# %%
file_location = os.path.join('crashes.json')
crash_neighborhood_merge_clean.to_json(file_location)

# %%
# finalhtml = crash_neighborhood_merge_clean.to_html('crashes.html')
